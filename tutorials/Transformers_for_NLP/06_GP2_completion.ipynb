# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Set device (use GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load pre-trained model and tokenizer
model_name = "gpt2-large"  # Options: "gpt2", "gpt2-medium", "gpt2-large", "gpt2-xl"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# Move model to device
model.to(device)

# Set model to evaluation mode
model.eval()

# Function to generate text
def generate_text(prompt, max_length=100, temperature=1.0, top_k=50, top_p=0.95, num_return_sequences=1):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)

    # Generate text
    with torch.no_grad():  # Disable gradient computation for inference
        outputs = model.generate(
            inputs,
            max_length=max_length,
            temperature=temperature,  # Controls randomness (lower = more focused, higher = more creative)
            top_k=top_k,  # Limits sampling to top-k most likely tokens
            top_p=top_p,  # Nucleus sampling: considers top tokens summing to top_p probability
            num_return_sequences=num_return_sequences,  # Number of sequences to generate
            pad_token_id=tokenizer.eos_token_id,  # Set padding token to EOS token
            do_sample=True,  # Enable sampling (vs. greedy decoding)
            no_repeat_ngram_size=2  # Avoid repeating 2-grams
        )

    # Decode and return generated text
    generated_texts = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return generated_texts

# Example usage
prompt = "Once upon a time in a distant galaxy"
generated_texts = generate_text(prompt, max_length=150, temperature=0.7, top_k=50, top_p=0.95, num_return_sequences=3)

# Print results
for i, text in enumerate(generated_texts, 1):
    print(f"Generated Text {i}: {text}\n")

# Optional: Interactive loop for multiple prompts
while True:
    user_prompt = input("Enter a prompt (or 'quit' to exit): ")
    if user_prompt.lower() == 'quit':
        break
    generated_texts = generate_text(user_prompt, max_length=150, temperature=0.7, top_k=50, top_p=0.95)
    print("Generated Text: ", generated_texts[0])
# Out:
# Using device: cuda
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Generated Text 1: Once upon a time in a distant galaxy, the universe was formed out of a single, tiny point of matter. In order to create matter, one point had to be destroyed. It was the act of this single point that gave rise to the Universe, and the destruction of that single particle caused the creation of the other matter in the galaxy.
#
# After that point was destroyed, another point began to form. This point would go on to destroy itself, creating another universe. Eventually, this point created the first black hole. The first point in our universe that created a blackhole was a point called the Big Bang. Now, we have a universe with two black holes, each of which is about the size of our sun. As these two
#
# Generated Text 2: Once upon a time in a distant galaxy, the galaxy was destroyed.
#
# The galaxy's survivors fled to other galaxies, only to find that they had lost their homeworlds. These worlds were lost to the void. The galaxy is now a place of perpetual war, where people from all over the universe must compete to survive.
#
# Generated Text 3: Once upon a time in a distant galaxy, a man named John Henry Watson built an automated machine that could read minds. He called it the "Eyes of the Machine." Watson believed that humans could be made more intelligent by learning from machines. In the early years of his career, Watson's vision was realized through the use of computers to read the minds of other people. But as computers grew more powerful, they became more difficult to control.
#
# John Watson worked on his vision for a long time. After many failures, he developed a device that looked like a pair of glasses. The device read people's minds through a camera, and the camera recorded images of people through an optic fiber. Watson also worked with a group of researchers at the
#
# Enter a prompt (or 'quit' to exit): explain quantum mechanics
# Generated Text:  explain quantum mechanics.
#
# "It's really quite easy to get people to believe that if you just throw out all the weird stuff that they think they know about the world, they'll have the same understanding of the universe that you have. That's not what happens," he said. "They're not going to understand the real world until they're willing to throw away all their preconceptions."
# , which he called "a very good book" that "showed a lot of evidence for quantum gravity." But he also said he was "not an expert in it." He also questioned the book's ability to explain the strange behavior of light, and said the author's use of quantum physics as a tool to make a point about free
